# %%
import pandas as pd
import numpy as np

# %%
n = 0
while n<1000:
    
    from route_imports.ratio_map import metric_to_url_map
    from route_imports.ratio_map import url_to_var_name_map
    from route_imports.ratio_map import url_to_name_map
    from route_imports.ratio_map import fin_statement_raw_names
    from route_imports.ratio_map import fin_statement_renamed_cols
    from route_imports.ratio_map import fin_statement_renamed_titles
    from route_imports.ratio_map import metric_to_formula_map
    from route_imports.ratio_map import url_to_metric_map
    from route_imports.ratio_map import url_to_equation_map
    from route_imports.ratio_map import url_to_definition_map
    from route_imports.ratio_map import fin_statement_title_links_dict
    import scipy
    from route_imports.ratio_map import fin_statement_title_statements_dict
    n+=1

# %%
while n<1000:
    sales= fin_statement_title_statements_dict["Net Revenue (Sales)"]
    n+=1

# %%
df = pd.read_csv("year~AAPL~cash_flow_statement.csv")

# %%
df =  df.loc[:, 'date':'link']

# %%
df =  df.loc[:, 'date':'link']
L = ['other','Other']
df =  df.loc[:, ~df.columns.str.contains('|'.join(L))]

# %%
# original_df = df
# original_df

# %%
fin_statements_matching = pd.read_csv("D:/Cloud/rclone/OneDrive/Web/TenDollarData/reference_data/Financial_Statements_Reference_Matching.csv")

# %%
n = 0
while n<1000:
    sales=  fin_statements_matching[fin_statements_matching['Title']=="Cash and Cash Equivalents"]["statement_url"][0]
    n+=1

# %%
import os

# %%
# all_titles = list(df)
# all_numbers_df = df[list(df.select_dtypes(include=['float','int64']))].div(4, axis=0)
# all_objects_df = df[list(df.select_dtypes(include=['object']))]
# concat_df = pd.concat([all_numbers_df, all_objects_df], axis=1)
# df = concat_df[all_titles]

# %%
# all_numbers_df = df[list(df.select_dtypes(include=['float','int64']))].div(4, axis=0)
df_row_1 = (df.select_dtypes(include=['float','int64']))[0:1].reset_index()
df_row_2 = (df.select_dtypes(include=['float','int64']))[1:2].reset_index()

# %%
len_yoy = len(df)

# %%
df
# Out:
#           date symbol          fillingDate         acceptedDate period  \
# 0   2020-09-26   AAPL           2020-10-30  2020-10-29 18:06:25     FY
# 1   2019-09-28   AAPL  2019-10-31 00:00:00  2019-10-30 18:12:36     FY
# 2   2018-09-29   AAPL  2018-11-05 00:00:00  2018-11-05 08:01:40     FY
# 3   2017-09-30   AAPL  2017-11-03 00:00:00  2017-11-03 08:01:37     FY
# 4   2016-09-24   AAPL  2016-10-26 00:00:00  2016-10-26 16:42:16     FY
# 5   2015-09-26   AAPL  2015-10-28 00:00:00  2015-10-28 16:31:09     FY
# 6   2014-09-27   AAPL  2014-10-27 00:00:00  2014-10-27 17:11:55     FY
# 7   2013-09-28   AAPL  2013-10-30 00:00:00  2013-10-29 20:38:28     FY
# 8   2012-09-29   AAPL  2012-10-31 00:00:00  2012-10-31 17:07:19     FY
# 9   2011-09-24   AAPL  2011-10-26 00:00:00  2011-10-26 16:35:25     FY
# 10  2010-09-25   AAPL  2010-10-27 00:00:00  2010-10-27 16:36:21     FY
# 11  2009-09-26   AAPL  2009-10-27 00:00:00  2009-10-27 16:18:29     FY
# ...

# %%
df = df[0:5]
df[len_yoy-1:len_yoy]
# Out:
#          date symbol          fillingDate         acceptedDate period  \
# 4  2016-09-24   AAPL  2016-10-26 00:00:00  2016-10-26 16:42:16     FY
#
#      netIncome  depreciationAndAmortization  deferredIncomeTax  \
# 4  45687000000                  10505000000       4.938000e+09
#
#    stockBasedCompensation  changeInWorkingCapital  ...  dividendsPaid  \
# 4            4.210000e+09             19095000000  ...  -1.215000e+10
#
#    netCashUsedProvidedByFinancingActivities  effectOfForexChangesOnCash  \
# 4                             -2.089000e+10                         0.0
#
#    netChangeInCash  cashAtEndOfPeriod  cashAtBeginningOfPeriod  \
# 4     -636000000.0        20484000000              21120000000
#
#    operatingCashFlow  capitalExpenditure  freeCashFlow  \
# 4        66231000000        -12734000000   53497000000
#
#                                                 link
# 4  https://www.sec.gov/Archives/edgar/data/320193...
#
# [1 rows x 32 columns]

# %%
fin_statement_title_links_dict ={
                                "Index": 'index',
                                "Date": 'date',
                                "Symbol": 'symbol',
                                "Filing Date": 'filing-date',
                                "Accepted Date": 'accepted-date',
                                "Period": 'period',
                                "Net Revenue (Sales)": 'revenue-sales',
                                "Cost of Revenue (Sales)": 'cost-of-sales-cost-of-revenue-cost-of-goods-sold',
                                "Gross Profit Margin": 'gross-profit-gross-income',
                                "Gross Profit Margin Ratio": 'gross-income-ratio-gross-profit-ratio',
                                "Research and Development (R&D)": 'research-and-development-expenses',
                                "Selling, General, and Administrative (SG&A)": 'selling-general-and-administrative-expenses',
                                "Selling & Marketing Expenses (S&M)": 's-and-m-selling-and-marketing-expenses',
                                "Other Income/Expenses, Net": 'other-expenses',
                                "Total Operating Expenses": 'operating-expenses',
                                "Cost & Expenses": 'cost-and-expenses',
                                "Interest Expense/Income, Net": 'interest-expense',
                                "Depreciation & Amortization (D&A)": 'depreciation-and-amortization',
                                "EBITDA": 'ebitda',
                                "EBITDA Margin": 'ebitda-ratio',
                                "Operating Income": 'operating-income',
                                "Operating Margin": 'operating-income-ratio',
                                "Total Other Income/Expenses": 'other-income-other-expenses-net',
                                "Pretax Income (Earnings)": 'income-before-tax-provisions',
                                "Pretax Income (Earnings) Margin": 'income-before-tax-ratio',
                                "Provision For Income Taxes": 'income-tax-expense-provisions',
                                "netIncome": 'net-income',
                                "Profit Margin": 'net-income-ratio',
                                "Earnings Per Share (EPS)": 'eps-earnings-per-share',
                                "Earnings Per Share (EPS) Diluted": 'eps-earnings-per-share-diluted',
                                "Shares Outstanding": 'shares-outstanding',
                                "Shares Outstanding (Diluted)": 'shares-outstanding-weighted-diluted',
                                "sec_filing_link',": 'sec_filing_link',
                                "sec_statement_link',": 'sec_statement_link',
                                "Cash and Cash Equivalents": 'cash-and-cash-equivalents',
                                "Short Term Investments": 'short-term-investments',
                                "Cash And Short-Term Investments": 'cash-and-short-term-investments',
                                "Inventory": 'net-receivables',
                                "Other Current Assets": 'inventory',
                                "Total Current Assets": 'total-current-assets',
                                "PP&E": 'pp-and-e',
                                "Goodwill": 'goodwill',
                                "Intangible Assets": 'intangible-assets',
                                "Goodwill and Intangible Assets": 'goodwill-and-intangible-assets',
                                "Long-term Investments": 'long-term-investments',
                                "Tax Assets": 'tax-assets',
                                "Other Assets": 'other-assets',
                                "Total Assets": 'total-assets',
                                "Accounts Payables": 'accounts-payables',
                                "Short-term Debt": 'short-term-debt',
                                "Income Tax Payables": 'tax-payables',
                                "Deferred Revenue": 'deferred-revenue',
                                "Other Current Liabilities": 'other-current-liabilities',
                                "Total Current Liabilities": 'total-current-liabilities',
                                "Long-term Debt": 'long-term-debt',
                                "Deferred Revenue Non-Current": 'deferred-revenue-non-current',
                                "Deferred Tax Liabilities Non-Current": 'deferred-tax-liabilities-non-current',
                                "Other Non-Current Liabilities": 'other-non-current-liabilities',
                                "Total Non-Current Liabilities": 'total-non-current-liabilities',
                                "Other Liabilities": 'other-liabilities',
                                "Total Liabilities": 'total-liabilities',
                                "Common Stock": 'common-stock',
                                "Retained Earnings": 'retained-earnings',
                                "Accumulated Other Comprehensive Income Loss": 'accumulated-other-comprehensive-income-loss',
                                "Other Shareholders Equity": 'other-total-stockholders-equity',
                                "Total Shareholders Equity": 'total-stockholders-equity',
                                "Total Liabilities & Stockholders Equity": 'total-liabilities-and-stockholders-equity',
                                "Total Investments": 'total-investments',
                                "Total Debt": 'total-debt',
                                "Net Debt": 'net-debt',
                                "Deferred Income Tax": 'deferred-income-tax',
                                "Stock-Based Compensation (SBC)": 'stock-based-compensation',
                                "Change in Working Capital": 'change-in-working-capital',
                                "Accounts Receivables": 'accounts-receivable',
                                "Other Working Capital": 'other-working-capital',
                                "Other Non-Cash Items": 'other-non-cash-items',
                                "Net Cash Provided by Operating Activities": 'net-cash-provided-by-operating-activities',
                                "Investments in PP&E": 'investments-in-property-plant-and-equipment',
                                "Acquisitions (Net)": 'acquisitions-net',
                                "Purchase of Investments": 'purchases-of-investments',
                                "Sales/Maturities of Investments": 'sales-maturities-of-investments',
                                "Other Investing Activities": 'other-investing-activities',
                                "Net Cash used for Investing Activities": 'net-cash-used-for-investing-activities',
                                "Debt Repayment": 'debt-repayment',
                                "Common Stock Issued": 'common-stock-issued',
                                "Common Stock Repurchased": 'common-stock-repurchased',
                                "Dividends Paid": 'dividends-paid',
                                "Other Financing Activities": 'other-financing-activities',
                                "Net Cash Used Provided by Financing Activities": 'net-cash-used-provided-by-financing-activities',
                                "Effect of Exchange Rate Changes on Cash": 'effect-of-forex-changes-on-cash',
                                "Net Change in Cash": 'net-change-in-cash',
                                "Cash at End of Period": 'cash-at-end-of-period',
                                "Cash at Beginning of Period": 'cash-at-beginning-of-period',
                                "Operating Cash Flow": 'operating-cash-flow',
                                "Capital Expenditure (capex)": 'capital-expenditure',
                                "Free Cash Flow": 'free-cash-flow',
                                "QQ-YYYY": 'QQ-YYYY',
                                "Year": 'Year',
                                }

# %%
fin_statement_title_links_dict["netIncome"]
# Out:
# 'net-income'

# %%
len_yoy = len(df)

# %%
df[0:1]
# Out:
#          date symbol fillingDate         acceptedDate period    netIncome  \
# 0  2020-09-26   AAPL  2020-10-30  2020-10-29 18:06:25     FY  57411000000
#
#    depreciationAndAmortization  deferredIncomeTax  stockBasedCompensation  \
# 0                  11056000000       -215000000.0            6.829000e+09
#
#    changeInWorkingCapital  ...  dividendsPaid  \
# 0            -18780000000  ...  -1.408100e+10
#
#    netCashUsedProvidedByFinancingActivities  effectOfForexChangesOnCash  \
# 0                             -8.682000e+10                         0.0
#
#    netChangeInCash  cashAtEndOfPeriod  cashAtBeginningOfPeriod  \
# 0    -1.043500e+10        39789000000              50224000000
#
#    operatingCashFlow  capitalExpenditure  freeCashFlow  \
# 0        80674000000          7309000000   73365000000
#
#                                                 link
# 0  https://www.sec.gov/Archives/edgar/data/320193...
#
# [1 rows x 32 columns]

# %%
df[5:6]
# Out:
#          date symbol          fillingDate         acceptedDate period  \
# 5  2015-09-26   AAPL  2015-10-28 00:00:00  2015-10-28 16:31:09     FY
#
#      netIncome  depreciationAndAmortization  deferredIncomeTax  \
# 5  53394000000                  11257000000       1.382000e+09
#
#    stockBasedCompensation  changeInWorkingCapital  ...  dividendsPaid  \
# 5            3.586000e+09              3685000000  ...  -1.156100e+10
#
#    netCashUsedProvidedByFinancingActivities  effectOfForexChangesOnCash  \
# 5                             -1.771600e+10                         0.0
#
#    netChangeInCash  cashAtEndOfPeriod  cashAtBeginningOfPeriod  \
# 5     7.276000e+09        21120000000              13844000000
#
#    operatingCashFlow  capitalExpenditure  freeCashFlow  \
# 5        81266000000        -11488000000   69778000000
#
#                                                 link
# 5  https://www.sec.gov/Archives/edgar/data/320193...
#
# [1 rows x 32 columns]

# %%
len_yoy = len(df)
if len_yoy <= 5:
    df[len_yoy-1:len_yoy]
else: 
    df[5:6]

# %%
df[4:5]
# Out:
#          date symbol          fillingDate         acceptedDate period  \
# 4  2016-09-24   AAPL  2016-10-26 00:00:00  2016-10-26 16:42:16     FY
#
#      netIncome  depreciationAndAmortization  deferredIncomeTax  \
# 4  45687000000                  10505000000       4.938000e+09
#
#    stockBasedCompensation  changeInWorkingCapital  ...  dividendsPaid  \
# 4            4.210000e+09             19095000000  ...  -1.215000e+10
#
#    netCashUsedProvidedByFinancingActivities  effectOfForexChangesOnCash  \
# 4                             -2.089000e+10                         0.0
#
#    netChangeInCash  cashAtEndOfPeriod  cashAtBeginningOfPeriod  \
# 4     -636000000.0        20484000000              21120000000
#
#    operatingCashFlow  capitalExpenditure  freeCashFlow  \
# 4        66231000000        -12734000000   53497000000
#
#                                                 link
# 4  https://www.sec.gov/Archives/edgar/data/320193...
#
# [1 rows x 32 columns]

# %%
df[20:21]
# Out:
#           date symbol          fillingDate         acceptedDate period  \
# 20  2000-09-30   AAPL  2000-12-14 00:00:00  2000-12-14 00:00:00     FY
#
#     netIncome  depreciationAndAmortization  deferredIncomeTax  \
# 20  786000000                     84000000        163000000.0
#
#     stockBasedCompensation  changeInWorkingCapital  ...  dividendsPaid  \
# 20                     0.0               157000000  ...            0.0
#
#     netCashUsedProvidedByFinancingActivities  effectOfForexChangesOnCash  \
# 20                                       0.0                         0.0
#
#     netChangeInCash  cashAtEndOfPeriod  cashAtBeginningOfPeriod  \
# 20              0.0         1191000000               1326000000
#
#     operatingCashFlow  capitalExpenditure  freeCashFlow  \
# 20          826000000          -107000000     719000000
#
#                                                  link
# 20  https://www.sec.gov/Archives/edgar/data/320193...
#
# [1 rows x 32 columns]

# %%
df[5:6]
# Out:
#          date symbol          fillingDate         acceptedDate period  \
# 5  2015-09-26   AAPL  2015-10-28 00:00:00  2015-10-28 16:31:09     FY
#
#      netIncome  depreciationAndAmortization  deferredIncomeTax  \
# 5  53394000000                  11257000000       1.382000e+09
#
#    stockBasedCompensation  changeInWorkingCapital  ...  dividendsPaid  \
# 5            3.586000e+09              3685000000  ...  -1.156100e+10
#
#    netCashUsedProvidedByFinancingActivities  effectOfForexChangesOnCash  \
# 5                             -1.771600e+10                         0.0
#
#    netChangeInCash  cashAtEndOfPeriod  cashAtBeginningOfPeriod  \
# 5     7.276000e+09        21120000000              13844000000
#
#    operatingCashFlow  capitalExpenditure  freeCashFlow  \
# 5        81266000000        -11488000000   69778000000
#
#                                                 link
# 5  https://www.sec.gov/Archives/edgar/data/320193...
#
# [1 rows x 32 columns]

# %%
df_yoy = (df_row_1.div(df_row_2))-1

# %%
df_yoy
# Out:
#    index  netIncome  depreciationAndAmortization  deferredIncomeTax  \
# 0   -1.0      0.039                    -0.118833          -0.367647
#
#    stockBasedCompensation  changeInWorkingCapital  accountsReceivables  \
# 0                0.125412               -1.450457            27.232653
#
#    inventory  accountsPayables  netCashProvidedByOperatingActivities  ...  \
# 0  -0.560554          1.112324                                0.1626  ...
#
#    commonStockRepurchased  dividendsPaid  \
# 0                 0.09441      -0.002691
#
#    netCashUsedProvidedByFinancingActivities  effectOfForexChangesOnCash  \
# 0                                 -0.045682                         NaN
#
#    netChangeInCash  cashAtEndOfPeriod  cashAtBeginningOfPeriod  \
# 0         -1.42923          -0.207769                 0.938178
#
#    operatingCashFlow  capitalExpenditure  freeCashFlow
# 0             0.1626           -1.696427       0.24567
#
# [1 rows x 27 columns]

# %%
# df[df["netIncome"]>1]
greater_than = (df_yoy[list(df_yoy)]>0.14) & (df_yoy[list(df_yoy)]<10)
less_than = (df_yoy[list(df_yoy)]<-0.14) & (df_yoy[list(df_yoy)]>-10)
not_zero = (df_yoy[list(df_yoy)] != -1)
df_yoyx = df_yoy[((greater_than) | (less_than)) & not_zero]

# %%
df_yoyx[list(df_yoyx.select_dtypes(include=['float','int64']))]
# Out:
#    index  netIncome  depreciationAndAmortization  deferredIncomeTax  \
# 0    NaN        NaN                          NaN          -0.367647
#
#    stockBasedCompensation  changeInWorkingCapital  accountsReceivables  \
# 0                     NaN               -1.450457                  NaN
#
#    inventory  accountsPayables  netCashProvidedByOperatingActivities  ...  \
# 0  -0.560554          1.112324                                0.1626  ...
#
#    commonStockRepurchased  dividendsPaid  \
# 0                     NaN            NaN
#
#    netCashUsedProvidedByFinancingActivities  effectOfForexChangesOnCash  \
# 0                                       NaN                         NaN
#
#    netChangeInCash  cashAtEndOfPeriod  cashAtBeginningOfPeriod  \
# 0         -1.42923          -0.207769                 0.938178
#
#    operatingCashFlow  capitalExpenditure  freeCashFlow
# 0             0.1626           -1.696427       0.24567
#
# [1 rows x 27 columns]

# %%
df_yoyx.dropna(axis=1, how='all')
# Out:
#    deferredIncomeTax  changeInWorkingCapital  inventory  accountsPayables  \
# 0          -0.367647               -1.450457  -0.560554          1.112324
#
#    netCashProvidedByOperatingActivities  \
# 0                                0.1626
#
#    investmentsInPropertyPlantAndEquipment  acquisitionsNet  \
# 0                               -0.303573         1.442308
#
#    netCashUsedForInvestingActivites  debtRepayment  netChangeInCash  \
# 0                          -1.09345       0.434299         -1.42923
#
#    cashAtEndOfPeriod  cashAtBeginningOfPeriod  operatingCashFlow  \
# 0          -0.207769                 0.938178             0.1626
#
#    capitalExpenditure  freeCashFlow
# 0           -1.696427       0.24567

# %%
df_yoyx = df_yoyx.dropna(axis=1, how='all')

# %%
df_yoyx
# Out:
#    deferredIncomeTax  changeInWorkingCapital  inventory  accountsPayables  \
# 0          -0.367647               -1.450457  -0.560554          1.112324
#
#    netCashProvidedByOperatingActivities  \
# 0                                0.1626
#
#    investmentsInPropertyPlantAndEquipment  acquisitionsNet  \
# 0                               -0.303573         1.442308
#
#    netCashUsedForInvestingActivites  debtRepayment  netChangeInCash  \
# 0                          -1.09345       0.434299         -1.42923
#
#    cashAtEndOfPeriod  cashAtBeginningOfPeriod  operatingCashFlow  \
# 0          -0.207769                 0.938178             0.1626
#
#    capitalExpenditure  freeCashFlow
# 0           -1.696427       0.24567

# %%
df_yoyx_sorted = df_yoyx.iloc[0].sort_values(ascending=False)

# %%
df_yoyx_sorted
# Out:
# acquisitionsNet                           1.442308
# accountsPayables                          1.112324
# cashAtBeginningOfPeriod                   0.938178
# debtRepayment                             0.434299
# freeCashFlow                              0.245670
# operatingCashFlow                         0.162600
# netCashProvidedByOperatingActivities      0.162600
# cashAtEndOfPeriod                        -0.207769
# investmentsInPropertyPlantAndEquipment   -0.303573
# deferredIncomeTax                        -0.367647
# inventory                                -0.560554
# netCashUsedForInvestingActivites         -1.093450
# netChangeInCash                          -1.429230
# changeInWorkingCapital                   -1.450457
# capitalExpenditure                       -1.696427
# Name: 0, dtype: float64

# %%
df
# Out:
#           date symbol          fillingDate         acceptedDate period  \
# 0   2020-09-26   AAPL           2020-10-30  2020-10-29 18:06:25     FY
# 1   2019-09-28   AAPL  2019-10-31 00:00:00  2019-10-30 18:12:36     FY
# 2   2018-09-29   AAPL  2018-11-05 00:00:00  2018-11-05 08:01:40     FY
# 3   2017-09-30   AAPL  2017-11-03 00:00:00  2017-11-03 08:01:37     FY
# 4   2016-09-24   AAPL  2016-10-26 00:00:00  2016-10-26 16:42:16     FY
# 5   2015-09-26   AAPL  2015-10-28 00:00:00  2015-10-28 16:31:09     FY
# 6   2014-09-27   AAPL  2014-10-27 00:00:00  2014-10-27 17:11:55     FY
# 7   2013-09-28   AAPL  2013-10-30 00:00:00  2013-10-29 20:38:28     FY
# 8   2012-09-29   AAPL  2012-10-31 00:00:00  2012-10-31 17:07:19     FY
# 9   2011-09-24   AAPL  2011-10-26 00:00:00  2011-10-26 16:35:25     FY
# 10  2010-09-25   AAPL  2010-10-27 00:00:00  2010-10-27 16:36:21     FY
# 11  2009-09-26   AAPL  2009-10-27 00:00:00  2009-10-27 16:18:29     FY
# ...

# %%
df.loc[df['netIncome'] > 55256000000, 'depreciationAndAmortization'] = np.nan

# %%
sorted(df_yoyx_sorted)
# Out:
# [-1.6964268699380658,
#  -1.4504569331510397,
#  -1.429229566862737,
#  -1.0934504096217534,
#  -0.560553633217993,
#  -0.36764705882352944,
#  -0.3035731300619342,
#  -0.2077691940108315,
#  0.16260033721952416,
#  0.16260033721952416,
#  0.24567033414832928,
#  0.43429869392390685,
#  0.9381777486203835,
#  1.1123244929797194,
#  1.4423076923076925]

# %%
df_yoyx.sample(5, axis=1)
# Out:
#    netCashUsedForInvestingActivites  operatingCashFlow  accountsPayables  \
# 0                          -1.09345             0.1626          1.112324
#
#    netChangeInCash  cashAtEndOfPeriod
# 0         -1.42923          -0.207769

# %%
df_dup = df_yoyx.sample(30, axis=1,replace=True)

# %%
df_dup.loc[:,~df_dup.columns.duplicated()]
# Out:
# ['deferredIncomeTax',
#  'cashAtEndOfPeriod',
#  'netCashUsedForInvestingActivites',
#  'capitalExpenditure',
#  'changeInWorkingCapital',
#  'debtRepayment',
#  'netCashProvidedByOperatingActivities',
#  'operatingCashFlow',
#  'acquisitionsNet',
#  'netChangeInCash',
#  'freeCashFlow',
#  'inventory',
#  'investmentsInPropertyPlantAndEquipment']

# %%
if len(df_dup)

# %%
list(df_yoyx.sample(30, axis=1,replace=True))
# Out:
# ['inventory',
#  'cashAtBeginningOfPeriod',
#  'freeCashFlow',
#  'cashAtEndOfPeriod',
#  'cashAtBeginningOfPeriod',
#  'netCashProvidedByOperatingActivities',
#  'debtRepayment',
#  'changeInWorkingCapital',
#  'accountsPayables',
#  'netChangeInCash',
#  'operatingCashFlow',
#  'netChangeInCash',
#  'netChangeInCash',
#  'accountsPayables',
#  'operatingCashFlow',
#  'capitalExpenditure',
#  'cashAtBeginningOfPeriod',
#  'accountsPayables',
#  'freeCashFlow',
#  'debtRepayment',
#  'netCashProvidedByOperatingActivities',
#  'freeCashFlow',
#  'cashAtBeginningOfPeriod',
#  'operatingCashFlow',
#  'debtRepayment',
#  'cashAtEndOfPeriod',
#  'acquisitionsNet',
#  'capitalExpenditure',
#  'accountsPayables',
#  'cashAtEndOfPeriod']

# %%
df_yoyx_5 = df_yoyx.sample(5, axis=1)

# %%
for x in list(df_yoyx_5):
    print(df_yoyx_5[x][0])
# Out:
# 0.16260033721952416
# -0.2077691940108315
# 0.16260033721952416
# 0.43429869392390685
# -0.3035731300619342

# %%
df_yoyx.iloc[0].sort_values(ascending=False)
# Out:
# acquisitionsNet                           1.442308
# accountsPayables                          1.112324
# cashAtBeginningOfPeriod                   0.938178
# debtRepayment                             0.434299
# freeCashFlow                              0.245670
# operatingCashFlow                         0.162600
# netCashProvidedByOperatingActivities      0.162600
# cashAtEndOfPeriod                        -0.207769
# investmentsInPropertyPlantAndEquipment   -0.303573
# otherWorkingCapital                      -0.328891
# deferredIncomeTax                        -0.367647
# inventory                                -0.560554
# netCashUsedForInvestingActivites         -1.093450
# netChangeInCash                          -1.429230
# changeInWorkingCapital                   -1.450457
# capitalExpenditure                       -1.696427
# Name: 0, dtype: float64

# %%
df_yoyx_5
# Out:
#    netCashProvidedByOperatingActivities  cashAtEndOfPeriod  operatingCashFlow  \
# 0                                0.1626          -0.207769             0.1626
#
#    debtRepayment  investmentsInPropertyPlantAndEquipment
# 0       0.434299                               -0.303573

# %%
    company_profiles_col = ['symbol',
                            'long name',
                            'currency',
                            'exchange',
                            'industry',
                            'description',
                            'sector',
                            'country',
                            'ipo date',
                            'short name',
                            'Industries',
                            'Similar Companies',
                            'shortest name',
                            'url name']
    company_profiles = company_profiles[company_profiles_col]

    profiles_dict = {}
    profiles_value = company_profiles[company_profiles['symbol']=="{}".format(url_symbol.upper())].values.tolist()[0]
    for n, profiles_col in enumerate(company_profiles_col):
        key = profiles_col
        value = profiles_value[n]
        profiles_dict[key] = value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-188-7f3331147a92> in <module>
#      13                         'shortest name',
#      14                         'url name']
# ---> 15 company_profiles = company_profiles[company_profiles_col]
#      16
#      17 profiles_dict = {}
#
# NameError: name 'company_profiles' is not defined

# %%
#     company_profiles_col = ['symbol',
#                             'long name',
#                             'currency',
#                             'exchange',
#                             'industry',
#                             'description',
#                             'sector',
#                             'country',
#                             'ipo date',
#                             'short name',
#                             'Industries',
#                             'Similar Companies',
#                             'shortest name',
#                             'url name']
#     company_profiles = company_profiles[company_profiles_col]

yoy_cards_dict = {}
profiles_value = df_yoyx_5.values.tolist()[0]
for n, profiles_col in enumerate(list(df_yoyx_5)):
    key = profiles_col
    value = profiles_value[n]
    yoy_cards_dict[key] = value

# %%
# list(profiles_dict.keys())[1]

yoy_1_key = list(yoy_cards_dict.items())[0][0]
yoy_1_value = list(yoy_cards_dict.items())[0][1]
yoy_2_key = list(yoy_cards_dict.items())[1][0]
yoy_2_value = list(yoy_cards_dict.items())[1][1]
yoy_3_key = list(yoy_cards_dict.items())[2][0]
yoy_3_value = list(yoy_cards_dict.items())[2][1]
yoy_4_key = list(yoy_cards_dict.items())[3][0]
yoy_4_value = list(yoy_cards_dict.items())[3][1]
yoy_5_key = list(yoy_cards_dict.items())[4][0]
yoy_5_value = list(yoy_cards_dict.items())[4][1]

# %%
next(iter(profiles_dict))
# Out:
# 'netCashProvidedByOperatingActivities'

# %%
profiles_dict[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-179-944e0239c703> in <module>
# ----> 1 profiles_dict[1]
#
# KeyError: 1

# %%
        profiles_value = company_profiles[company_profiles['symbol']=="{}".format(url_symbol.upper())].values.tolist()[0]

# %%
list(df_yoyx_5)
# Out:
# ['netCashProvidedByOperatingActivities',
#  'cashAtEndOfPeriod',
#  'operatingCashFlow',
#  'debtRepayment',
#  'investmentsInPropertyPlantAndEquipment']

# %%
yoy_cards_dict = {}

# %%
for n, key in enumerate(list(df_yoyx_5)):
    value = yoy_cards_dict[n]
    df_yoyx_5[key] = value
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-173-c5825e455bb6> in <module>
#       1 for n, key in enumerate(list(df_yoyx_5)):
# ----> 2     value = yoy_cards_dict[n]
#       3     df_yoyx_5[key] = value
#
# KeyError: 0

# %%
df_yoyx
# Out:
#    index  netIncome  depreciationAndAmortization  deferredIncomeTax  \
# 0    NaN        NaN                          NaN                NaN
#
#    stockBasedCompensation  changeInWorkingCapital  accountsReceivables  \
# 0                     NaN                     NaN                  NaN
#
#    inventory  accountsPayables  otherWorkingCapital  ...  dividendsPaid  \
# 0        NaN          2.112324                  NaN  ...            NaN
#
#    otherFinancingActivites  netCashUsedProvidedByFinancingActivities  \
# 0                      NaN                                       NaN
#
#    effectOfForexChangesOnCash  netChangeInCash  cashAtEndOfPeriod  \
# 0                         NaN              NaN                NaN
#
#    cashAtBeginningOfPeriod  operatingCashFlow  capitalExpenditure  \
# 0                 1.938178                NaN                 NaN
#
#    freeCashFlow
# 0       1.24567
#
# [1 rows x 31 columns]

# %%
df_yoy[df_yoy[list(df_yoy)]>.2]
# Out:
#    index  netIncome  depreciationAndAmortization  deferredIncomeTax  \
# 0    NaN      1.039                     0.881167           0.632353
#
#    stockBasedCompensation  changeInWorkingCapital  accountsReceivables  \
# 0                1.125412                     NaN            28.232653
#
#    inventory  accountsPayables  otherWorkingCapital  ...  dividendsPaid  \
# 0   0.439446          2.112324             0.671109  ...       0.997309
#
#    otherFinancingActivites  netCashUsedProvidedByFinancingActivities  \
# 0                      NaN                                  0.954318
#
#    effectOfForexChangesOnCash  netChangeInCash  cashAtEndOfPeriod  \
# 0                         NaN              NaN           0.792231
#
#    cashAtBeginningOfPeriod  operatingCashFlow  capitalExpenditure  \
# 0                 1.938178             1.1626                 NaN
#
#    freeCashFlow
# 0       1.24567
#
# [1 rows x 31 columns]

# %%
# df_row_1.div(df_row_2).to_dict()

# %%
list(df)
# Out:
# ['Unnamed: 0',
#  'index',
#  'date',
#  'symbol',
#  'filing_date',
#  'accepted_date',
#  'period',
#  'net_revenue',
#  'cost_of_sales',
#  'gross_profit_margin_non',
#  'gross_profit_margin_ratio',
#  'r_n_d',
#  'g_n_a',
#  's_n_m',
#  'other_income',
#  'total_opex',
#  'cost_expenses',
#  'interest_expense',
#  'd_n_a',
#  'ebitda_non',
#  'ebitda_margin',
#  'operating_income',
#  'operating_margin',
#  'total_other_income',
#  'pretax_income_non',
#  'pretax_income_margin',
#  'income_tax_expense',
#  'net_income',
#  'profit_margin',
#  'eps_non',
#  'eps_diluted',
#  'shares_outstanding_non',
#  'shares_outstanding_diluted',
#  'sec_filing_link',
#  'sec_statement_link',
#  'cash_non',
#  'short_term_investments',
#  'cash_n_short_term_investments',
#  'inventory',
#  'other_current_assets',
#  'total_current_assets',
#  'pp_n_e',
#  'goodwill',
#  'intangible_assets',
#  'goodwill_n_intangible_assets',
#  'long_term_investments',
#  'tax_assets',
#  'other_assets',
# ...

# %%
 df.iloc[:, 0:2]
# Out:
#     Unnamed: 0  index
# 0         1727    0.0
# 1         1635    0.0
# 2         1551    0.0
# 3         1511    0.0
# 4         1431    0.0
# 5         1387    0.0
# 6         1299    0.0
# 7         1251    0.0
# 8         1195    0.0
# 9         1135    0.0
# 10        1071    0.0
# 11        1003    0.0
# 12         939    0.0
# 13         863    0.0
# 14         819    0.0
# 15         747    0.0
# 16         675    0.0
# 17         631    0.0
# 18         551    0.0
# 19         459    0.0
# 20         419    0.0
# 21         355    0.0
# 22         291    0.0
# 23         235    0.0
# 24         159    0.0
# 25         119    0.0
# 26          43    0.0

# %%
group_column = "symbol"

# %%
def replace(group, stds):
    group[np.abs(group - group.mean()) > stds * group.std()] = np.nan
    return group

# df is your DataFrame
# df.loc[:, df.columns != group_column] = 
# df.groupby(group_column).transform(lambda g: replace(g, 1))

# %%
df['pct_chg_temp'] = df['{}'.format("revenue_sales")]/df['{}'.format("revenue_sales")].shift(-4)

# %%
# df['pct_chg_temp'].values[df['pct_chg_temp'] > 10] = np.nan

# %%
df.loc[df['pct_chg_temp'] > 10, 'revenue_sales'] = np.nan

# %%
df.tail(30)
# Out:
#      Unnamed: 0  index  Unnamed: 0.1        date symbol          filing_date  \
# 78           78     19           0.0  2001-06-30   AAPL           2001-12-21
# 79           79     19           0.0  2001-03-31   AAPL           2001-12-21
# 80           80     20           0.0  2000-12-31   AAPL  2000-12-14 00:00:00
# 81           81     20           0.0  2000-09-30   AAPL  2000-12-14 00:00:00
# 82           82     20           0.0  2000-06-30   AAPL  2000-12-14 00:00:00
# 83           83     20           0.0  2000-03-31   AAPL  2000-12-14 00:00:00
# 84           84     21           0.0  1999-12-31   AAPL  1999-12-22 00:00:00
# 85           85     21           0.0  1999-09-30   AAPL  1999-12-22 00:00:00
# 86           86     21           0.0  1999-06-30   AAPL  1999-12-22 00:00:00
# 87           87     21           0.0  1999-03-31   AAPL  1999-12-22 00:00:00
# 88           88     22           0.0  1998-12-31   AAPL                  NaN
# ...

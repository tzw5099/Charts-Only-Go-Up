# %%
import glob
import pandas as pd
import time
import os

# %%
start_time = time.time()
uri_list = "cash-and-cash-equivalents"
url_symbol_name = "apple"
url_symbol = "aapl"
url_fin_metric = "cash-and-cash-equivalents"
def magnitude_num(number, currency_symbol):
    if len(str(number)) > 9:
        magnitude = number/1000000000
        magnitude_str = "{}{}{}".format(currency_symbol,round(magnitude,1),"B")
    elif len(str(number)) > 6:
        magnitude = number/1000000
        magnitude_str = "{}{}{}".format(currency_symbol,round(magnitude,1),"M")
    elif len(str(number)) > 3:
        magnitude = number/1000
        magnitude_str = "{}{}{}".format(currency_symbol,round(magnitude,1),"K")
    else:
        magnitude = number
        magnitude_str = "{}{}{}".format(currency_symbol,round(magnitude,1),"K")
    return magnitude_str
company_profiles = pd.read_csv("../reference_data/Company_Profiles.csv")#,sep=";", encoding='cp1252'()#, encoding='cp1252')
fin_statements_matching = pd.read_csv("../reference_data/Financial_Statements_Reference_Matching.csv")#, encoding='cp1252')
currency_symbol = list(company_profiles[company_profiles['symbol']=="{}".format(url_symbol.upper())]['currency symbol'])[0]
company_profiles_col = ['symbol',
                        'long name',
                        'currency',
                        'exchange',
                        'industry',
                        'description',
                        'sector',
                        'country',
                        'ipo date',
                        'short name','Industries','Similar Companies']
company_profiles = company_profiles[company_profiles_col]

# %%
# df
# fin_statements_matching
# company_profiles
perms = lambda xs: (list(x) for x in itertools.permutations(xs))
# https://stackoverflow.com/questions/16756174/python-one-line-function-definition
client_action_map = {
  'churn': perms,
  'engagement': perms,
}

# %%
profiles_dict = {}
profiles_value = company_profiles[company_profiles['symbol']=="{}".format(url_symbol.upper())].values.tolist()[0]

# %%
for n, profiles_col in enumerate(company_profiles_col):
    key = profiles_col
    value = profiles_value[n]
    profiles_dict[key] = value

# %%
chars_to_remove = ["'","[","]"]

for character in chars_to_remove:
    profiles_dict['Industries'] = profiles_dict['Industries'].replace(character, "")
    profiles_dict['Similar Companies'] = profiles_dict['Similar Companies'].replace(character, "")

# %%
ratios
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-dea26a916d06> in <module>
# ----> 1 ratios
#
# NameError: name 'ratios' is not defined

# %%
# profiles_dict['Industries'].replace("'","").replace("[","").replace("\","")
# ["'","[","]"]
# profiles_dict['Industries']
# chars_to_remove = ["'","[","]"]
# profiles_dict['Industries'].translate(None, ''.join(chars_to_remove)
# profiles_dict['Similar Companies'])

# %%
fin_statements_matching
# Out:
#      index  subindex                Name  Financial Statement  \
# 0        1         1                date     Income Statement
# 1        2         2              symbol     Income Statement
# 2        3         3         fillingDate     Income Statement
# 3        4         4        acceptedDate     Income Statement
# 4        5         5              period     Income Statement
# ..     ...       ...                 ...                  ...
# 112    112        33   operatingCashFlow  Cash Flow Statement
# 113    113        34  capitalExpenditure  Cash Flow Statement
# 114    114        35        freeCashFlow  Cash Flow Statement
# 115    115        36                link  Cash Flow Statement
# 116    116        37           finalLink  Cash Flow Statement
#
#                      URL        Variable Name                        Title  \
# 0                   date                 date                         Date
# 1                 symbol               symbol                       Symbol
# 2            filing-date          filing_date                  Filing Date
# 3          accepted-date        accepted_date                Accepted Date
# 4           quarter-year         quarter_year               Quarter & Year
# ..                   ...                  ...                          ...
# 112  operating-cash-flow  operating_cash_flow          Operating Cash Flow
# 113  capital-expenditure  capital_expenditure  Capital Expenditure (capex)
# 114       free-cash-flow       free_cash_flow               Free Cash Flow
# 115       sec-filing-url       sec_filing_url              SEC Filing Link
# 116    sec-statement-url    sec_statement_url           SEC Statement Link
#
#                                             Definition Python Variable Name  \
# 0                                                    -                 date
# 1                                                    -               symbol
# 2                                                    -          filing_date
# 3                                                    -        accepted_date
# 4                                                    -       quarter_n_year
# ..                                                 ...                  ...
# 112  Operating cash flow (OCF) is a measure of the ...  operating_cash_flow
# 113  Capital expenditures (capex) are funds used by...                capex
# 114  Free cash flow (FCF) represents the cash a com...       free_cash_flow
# 115                                                  -      sec_filing_link
# 116                                                  -   sec_statement_link
#
#                                       Definitions Link Also known as
# 0                                                    -           NaN
# 1                                                    -           NaN
# 2                                                    -           NaN
# 3                                                    -           NaN
# 4                                                    -           NaN
# ..                                                 ...           ...
# 112  https://www.investopedia.com/terms/o/operating...           NaN
# 113  https://www.investopedia.com/terms/c/capitalex...           NaN
# 114  https://www.investopedia.com/terms/f/freecashf...           NaN
# 115                                                  -             -
# 116                                                  -             -
#
# [117 rows x 11 columns]

# %%
profiles_dict = {}
profiles_value = company_profiles[company_profiles['symbol']=="{}".format(url_symbol.upper())].values.tolist()[0]

titles_bs = list(fin_statements_matching[fin_statements_matching['Financial Statement']=="Balance Sheet"]['Title'])
titles_cf = list(fin_statements_matching[fin_statements_matching['Financial Statement']=="Cash Flow Statement"]['Title'])
titles_is = list(fin_statements_matching[fin_statements_matching['Financial Statement']=="Income Statement"]['Title'])

urls_bs = list(fin_statements_matching[fin_statements_matching['Financial Statement']=="Balance Sheet"]['URL'])
urls_cf = list(fin_statements_matching[fin_statements_matching['Financial Statement']=="Cash Flow Statement"]['URL'])
urls_is = list(fin_statements_matching[fin_statements_matching['Financial Statement']=="Income Statement"]['URL'])


for n, profiles_col in enumerate(company_profiles_col):
    key = profiles_col
    value = profiles_value[n]
    profiles_dict[key] = value 

if "{}".format(url_fin_metric) in urls_is:
    fin_statement_dir = "Income Statement"
elif "{}".format(url_fin_metric) in urls_bs:
    fin_metric_pos = urls_bs.index("{}".format(url_fin_metric))
    fin_statement_dir = "Balance Sheet"
    fin_statement_cols = titles_bs
    cols = titles_bs
    fin_metric_title = fin_statement_cols[fin_metric_pos]

elif "{}".format(url_fin_metric) in urls_cf:
    fin_statement_dir = "Cash Flow Statement"

else:
    pass

# %%
# start_time = time.time()
csv_file = glob.glob("../Charts_TenDollarData/financial_statements/data/Historical Financial Statements/*/year/{}/*~{}~*".format(fin_statement_dir, url_symbol.upper()))[-1]

df = pd.read_csv(csv_file) #.format("NLOK"))[-1]
# df = df[df['date'].notna()]#fillna(method='ffill')
df = df[0:].iloc[::-1]#.dropna()
df_fin_statement = df
#region Pandas data manipulation
matching_row = fin_statements_matching[fin_statements_matching['URL']=="{}".format(url_fin_metric)]
fin_metric_title = list(matching_row['Title'])[0]
fin_metric_name = list(matching_row['Name'])[0]
print("fin metric name", fin_metric_name)
sorted_metric = df["{}".format(fin_metric_name)].sort_values()
# Out:
# fin metric name cashAndCashEquivalents

# %%
aapl_df = pd.read_csv('../Charts_TenDollarData/financial_statements/data/Historical Financial Statements/Technology/year/Balance Sheet/year~AAPL~balance_sheet.csv')

# %%
aapl_df
# Out:
#     Unnamed: 0        date symbol          fillingDate         acceptedDate  \
# 0            0  2020-09-26   AAPL           2020-10-30  2020-10-29 18:06:25
# 1            0  2019-09-28   AAPL  2019-10-31 00:00:00  2019-10-30 18:12:36
# 2            0  2018-09-29   AAPL  2018-11-05 00:00:00  2018-11-05 08:01:40
# 3            0  2017-09-30   AAPL  2017-11-03 00:00:00  2017-11-03 08:01:37
# 4            0  2016-09-24   AAPL  2016-10-26 00:00:00  2016-10-26 16:42:16
# 5            0  2015-09-26   AAPL  2015-10-28 00:00:00  2015-10-28 16:31:09
# 6            0  2014-09-27   AAPL  2014-10-27 00:00:00  2014-10-27 17:11:55
# 7            0  2013-09-28   AAPL  2013-10-30 00:00:00  2013-10-29 20:38:28
# 8            0  2012-09-29   AAPL  2012-10-31 00:00:00  2012-10-31 17:07:19
# 9            0  2011-09-24   AAPL  2011-10-26 00:00:00  2011-10-26 16:35:25
# 10           0  2010-09-25   AAPL  2010-10-27 00:00:00  2010-10-27 16:36:21
# 11           0  2009-09-26   AAPL  2009-10-27 00:00:00  2009-10-27 16:18:29
# 12           0  2008-09-27   AAPL  2008-11-05 00:00:00  2008-11-05 06:16:23
# 13           0  2007-09-29   AAPL  2007-11-15 00:00:00  2007-11-15 16:49:37
# 14           0  2006-09-30   AAPL           2006-12-29  2006-12-29 06:05:58
# 15           0  2005-09-24   AAPL           2005-12-01  2005-11-30 21:22:48
# 16           0  2004-09-25   AAPL           2004-12-03  2004-12-02 18:05:49
# 17           0  2003-09-27   AAPL           2003-12-19  2003-12-19 17:25:45
# 18           0  2002-09-28   AAPL  2002-12-19 00:00:00  2002-12-19 17:20:21
# 19           0  2001-09-29   AAPL           2001-12-21  2001-12-21 00:00:00
# 20           0  2000-09-30   AAPL  2000-12-14 00:00:00  2000-12-14 00:00:00
# 21           0  1999-09-25   AAPL  1999-12-22 00:00:00  1999-12-22 00:00:00
# 22           0  1998-09-25   AAPL                  NaN                  NaN
# 23           0  1997-09-26   AAPL  1997-12-05 00:00:00  1997-12-05 00:00:00
# 24           0  1996-09-27   AAPL  1996-12-19 00:00:00  1996-12-19 00:00:00
# 25           0  1995-09-29   AAPL  1995-12-19 00:00:00  1995-12-19 00:00:00
# 26           0  1994-09-30   AAPL  1994-12-13 00:00:00  1994-12-13 00:00:00
#
#    period  cashAndCashEquivalents  shortTermInvestments  \
# 0      FY             38016000000           52927000000
# 1      FY             48844000000           51713000000
# 2      FY             25913000000           40388000000
# 3      FY             20289000000           53892000000
# 4      FY             20484000000           46671000000
# 5      FY             21120000000           20481000000
# 6      FY             13844000000           11233000000
# 7      FY             14259000000           26287000000
# 8      FY             10746000000           18383000000
# 9      FY              9815000000           16137000000
# 10     FY             11261000000           14359000000
# 11     FY              5263000000           18201000000
# 12     FY             11875000000           12615000000
# 13     FY              9352000000            6034000000
# 14     FY              6392000000            3718000000
# 15     FY              3491000000            4770000000
# 16     FY              2969000000            2495000000
# 17     FY              3396000000            1170000000
# 18     FY              2252000000            2085000000
# 19     FY              2310000000            2026000000
# 20     FY              1191000000            2836000000
# 21     FY              1326000000            1900000000
# 22     FY              1481000000             819000000
# 23     FY              1230000000             229000000
# 24     FY              1552000000             193000000
# 25     FY               756000000             196000000
# 26     FY              1203488000              54368000
#
#     cashAndShortTermInvestments  netReceivables  ...  retainedEarnings  \
# 0                   90943000000     16120000000  ...       14966000000
# 1                  100557000000     45804000000  ...       45898000000
# 2                   66301000000     48995000000  ...       70400000000
# 3                   74181000000     35673000000  ...       98330000000
# 4                   67155000000     29299000000  ...       96364000000
# 5                   41601000000     30343000000  ...       92284000000
# 6                   25077000000     27219000000  ...       87152000000
# 7                   40546000000     20641000000  ...      104256000000
# 8                   29129000000     18692000000  ...      101289000000
# 9                   25952000000     11717000000  ...       62841000000
# 10                  25620000000      9924000000  ...       37169000000
# 11                  23464000000      5057000000  ...       23353000000
# 12                  24490000000      4704000000  ...       13845000000
# 13                  15386000000      4029000000  ...        9101000000
# 14                  10110000000      2845000000  ...        5607000000
# 15                   8261000000      1312000000  ...        4005000000
# 16                   5464000000      1050000000  ...        2670000000
# 17                   4566000000       766000000  ...        2394000000
# 18                   4337000000       565000000  ...        2325000000
# 19                   4336000000       466000000  ...        2260000000
# 20                   4027000000       953000000  ...        2285000000
# 21                   3226000000       681000000  ...        1499000000
# 22                   2300000000       955000000  ...         898000000
# 23                   1459000000      1035000000  ...         589000000
# 24                   1745000000      1496000000  ...        1634000000
# 25                    952000000      1931000000  ...        2464000000
# 26                   1257856000      1581347000  ...        2096206000
#
#     accumulatedOtherComprehensiveIncomeLoss  othertotalStockholdersEquity  \
# 0                             -4.060000e+08                  3.380224e+10
# 1                             -5.840000e+08                 -1.291000e+09
# 2                             -3.454000e+09                 -2.450000e+08
# 3                             -4.129300e+10                  0.000000e+00
# 4                              6.340000e+08                 -5.400000e+08
# 5                             -3.450000e+08                  3.080000e+08
# 6                              1.082000e+09                  1.324000e+09
# 7                             -4.710000e+08                 -3.660000e+08
# 8                              4.990000e+08                  4.910000e+08
# 9                              4.430000e+08                  4.200000e+08
# 10                            -4.600000e+07                  0.000000e+00
# 11                             7.700000e+07                  0.000000e+00
# 12                             8.000000e+06                  0.000000e+00
# 13                             6.300000e+07                  0.000000e+00
# 14                            -7.940000e+08                  0.000000e+00
# 15                            -6.640000e+08                 -6.000000e+07
# 16                            -1.080000e+08                 -9.300000e+07
# 17                            -9.700000e+07                 -6.200000e+07
# 18                            -5.600000e+07                 -7.000000e+06
# 19                            -3.300000e+07                 -1.100000e+07
# 20                            -3.870000e+08                  0.000000e+00
# 21                             1.060000e+08                  0.000000e+00
# 22                            -3.900000e+07                  0.000000e+00
# 23                            -7.400000e+07                 -3.700000e+07
# 24                            -3.000000e+07                 -1.500000e+07
# 25                             7.800000e+07                  3.900000e+07
# 26                            -7.850880e+08                  0.000000e+00
#
#     totalStockholdersEquity  totalLiabilitiesAndStockholdersEquity  \
# 0               65339000000                           323888000000
# 1               90488000000                           338516000000
# 2              107147000000                           365725000000
# 3              134047000000                           241272000000
# 4              128249000000                           321686000000
# 5              119355000000                           290345000000
# 6              111547000000                           231839000000
# 7              123549000000                           207000000000
# 8              118210000000                           176064000000
# 9               76615000000                           116371000000
# 10              47791000000                            75183000000
# 11              31640000000                            47501000000
# 12              21030000000                            39572000000
# 13              14532000000                            25347000000
# 14               9984000000                             7221000000
# 15               7466000000                            11551000000
# 16               5076000000                             8050000000
# 17               4223000000                             6815000000
# 18               4095000000                             6298000000
# 19               3920000000                             6021000000
# 20               4107000000                             2696000000
# 21               3104000000                             5161000000
# 22               1642000000                             4289000000
# 23               1200000000                             4233000000
# 24               2058000000                             5364000000
# 25               2901000000                             6231000000
# 26               2383301000                             2919445000
#
#     totalInvestments     totalDebt       netDebt  \
# 0       1.538140e+11  1.074400e+11  6.942400e+10
# 1       1.570540e+11  1.080470e+11  5.920300e+10
# 2       2.111870e+11  1.144830e+11  8.857000e+10
# 3       0.000000e+00  1.156800e+11  9.539100e+10
# 4       2.171010e+11  8.703200e+10  6.654800e+10
# 5       1.845460e+11  6.432800e+10  4.320800e+10
# 6       1.413950e+11  3.529500e+10  2.145100e+10
# 7       1.325020e+11  1.696000e+10  2.701000e+09
# 8       1.105050e+11  0.000000e+00 -1.074600e+10
# 9       7.175500e+10  0.000000e+00 -9.815000e+09
# 10      3.975000e+10  0.000000e+00 -1.126100e+10
# 11      2.872900e+10  0.000000e+00 -5.263000e+09
# 12      1.261500e+10  0.000000e+00 -1.187500e+10
# 13      6.034000e+09  0.000000e+00 -9.352000e+09
# 14      0.000000e+00  0.000000e+00 -6.392000e+09
# 15      4.770000e+09  0.000000e+00 -3.491000e+09
# 16      2.495000e+09  0.000000e+00 -2.969000e+09
# 17      1.170000e+09  3.040000e+08 -3.092000e+09
# 18      2.124000e+09  3.160000e+08 -1.936000e+09
# 19      2.154000e+09  3.170000e+08 -1.993000e+09
# 20      0.000000e+00  3.000000e+08 -8.910000e+08
# 21      2.239000e+09  3.000000e+08 -1.026000e+09
# 22      8.190000e+08  9.540000e+08 -5.270000e+08
# 23      2.290000e+08  9.760000e+08 -2.540000e+08
# 24      1.930000e+08  1.135000e+09 -4.170000e+08
# 25      1.960000e+08  7.640000e+08  8.000000e+06
# 26      0.000000e+00  5.966720e+08 -6.060000e+08
#
#                                                  link  \
# 0   https://www.sec.gov/Archives/edgar/data/320193...
# 1   https://www.sec.gov/Archives/edgar/data/320193...
# 2   https://www.sec.gov/Archives/edgar/data/320193...
# 3   https://www.sec.gov/Archives/edgar/data/320193...
# 4   https://www.sec.gov/Archives/edgar/data/320193...
# 5   https://www.sec.gov/Archives/edgar/data/320193...
# 6   https://www.sec.gov/Archives/edgar/data/320193...
# 7   https://www.sec.gov/Archives/edgar/data/320193...
# 8   https://www.sec.gov/Archives/edgar/data/320193...
# 9   https://www.sec.gov/Archives/edgar/data/320193...
# 10  https://www.sec.gov/Archives/edgar/data/320193...
# 11  https://www.sec.gov/Archives/edgar/data/320193...
# 12  https://www.sec.gov/Archives/edgar/data/320193...
# 13  https://www.sec.gov/Archives/edgar/data/320193...
# 14  https://www.sec.gov/Archives/edgar/data/320193...
# 15  https://www.sec.gov/Archives/edgar/data/320193...
# 16  https://www.sec.gov/Archives/edgar/data/320193...
# 17  https://www.sec.gov/Archives/edgar/data/320193...
# 18  https://www.sec.gov/Archives/edgar/data/320193...
# 19  https://www.sec.gov/Archives/edgar/data/320193...
# 20  https://www.sec.gov/Archives/edgar/data/320193...
# 21  https://www.sec.gov/Archives/edgar/data/320193...
# 22                                                NaN
# 23  https://www.sec.gov/Archives/edgar/data/320193...
# 24  https://www.sec.gov/Archives/edgar/data/320193...
# 25  https://www.sec.gov/Archives/edgar/data/320193...
# 26  https://www.sec.gov/Archives/edgar/data/320193...
#
#                                             finalLink
# 0   https://www.sec.gov/Archives/edgar/data/320193...
# 1   https://www.sec.gov/Archives/edgar/data/320193...
# 2   https://www.sec.gov/Archives/edgar/data/320193...
# 3   https://www.sec.gov/Archives/edgar/data/320193...
# 4   https://www.sec.gov/Archives/edgar/data/320193...
# 5   https://www.sec.gov/Archives/edgar/data/320193...
# 6   https://www.sec.gov/Archives/edgar/data/320193...
# 7   https://www.sec.gov/Archives/edgar/data/320193...
# 8   https://www.sec.gov/Archives/edgar/data/320193...
# 9   https://www.sec.gov/Archives/edgar/data/320193...
# 10  https://www.sec.gov/Archives/edgar/data/320193...
# 11  https://www.sec.gov/Archives/edgar/data/320193...
# 12  https://www.sec.gov/Archives/edgar/data/320193...
# 13  https://www.sec.gov/Archives/edgar/data/320193...
# 14  https://www.sec.gov/Archives/edgar/data/320193...
# 15  https://www.sec.gov/Archives/edgar/data/320193...
# 16  https://www.sec.gov/Archives/edgar/data/320193...
# 17  https://www.sec.gov/Archives/edgar/data/320193...
# 18  https://www.sec.gov/Archives/edgar/data/320193...
# 19  https://www.sec.gov/Archives/edgar/data/320193...
# 20  https://www.sec.gov/Archives/edgar/data/320193...
# 21  https://www.sec.gov/Archives/edgar/data/320193...
# 22                                                NaN
# 23  https://www.sec.gov/Archives/edgar/data/320193...
# 24  https://www.sec.gov/Archives/edgar/data/320193...
# 25  https://www.sec.gov/Archives/edgar/data/320193...
# 26  https://www.sec.gov/Archives/edgar/data/320193...
#
# [27 rows x 47 columns]

# %%
all_bs_abs_path = glob.glob("../Charts_TenDollarData/financial_statements/data/Historical Financial Statements/*/year/Balance Sheet/*")
all_is_abs_path = glob.glob("../Charts_TenDollarData/financial_statements/data/Historical Financial Statements/*/year/Income Statement/*")
all_cf_abs_path = glob.glob("../Charts_TenDollarData/financial_statements/data/Historical Financial Statements/*/year/Cash Flow Statement/*")
all_bs_abs_path
# Out:
# ['../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AAU~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ABX.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ACET~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ACH~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ADN.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AEM.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AEM~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AGI.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AGI~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AG~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AHGP~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AI.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AKE.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AKS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AKZA.AS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ALAMG.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ALBKK.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ALB~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ALCOG.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ALCOI.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ALCRB.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ALDUB.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ALEO2.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ALGLD.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ALHRG.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ALMOU.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ALO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ALS.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ALTR.LS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AMEBA.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AMG.AS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AMM.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AMRS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ANX.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~APAM.AS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~APA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~APD~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~APY.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AQA.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AR.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ARG.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ASH~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ASIX~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ASM~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ASR.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AUG.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AUG~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AUMN~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AUY~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AU~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AVD~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AVL.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AVTR~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AVTX.AS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AXS.AS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AXTA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AXU~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~AYM.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~BAK~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~BBL~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~BCC~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~BCPC~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~BHP~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~BIOX~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~BKI.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~BOS.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~BSX.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~BTG~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~BTO.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~BVN~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CADC~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CAL.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CAS.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CBPX~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CBT~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CCF~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CCM.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CC~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CDE~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CEE.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CENX~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CE~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CFF.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CFP.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CFX.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CF~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CG.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CGA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CGG.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CHNR~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CIA.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CINR~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CLF~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CLW~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CMC~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CMP~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CMT~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CNT.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~COR.LS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CPAC~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CRBN.AS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CRH~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CS.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CSTE~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CSTM~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CTVA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CWX.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~CX~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~DD~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~DNG.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~DNT.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~DOW~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~DPM.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~DRD~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~DSM.AS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ECL~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ECO.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~EDR.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~EDV.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~EGO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ELD.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ELR.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~EMN~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~EMX~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ENGB.BR~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~EOX.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~EQX~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ER.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ERA.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ERD.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ESI~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ESM.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ETG.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~EUR.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~EVA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~EXAC.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~EXK~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~EXN.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~EXPL.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~EXP~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~FAR.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~FCX~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~FELP~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~FF~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~FM.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~FMC~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~FNV.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~FNV~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~FOE~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~FR.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~FRD~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~FSI~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~FSM~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~FSY.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~FT.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~FUL~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~FVI.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~FVL.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GAU~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GCM.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GCP~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GDL.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GEO.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GEVO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GFI~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GGA.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GGB~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GGD.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GLT~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GMO.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GMO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GMX.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GOLD~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GORO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GPL~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GPR.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GPRE~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GRA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GRVO.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GSC.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GSM~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GSS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GSV~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GURE~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~GUY.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~HBM.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~HBM~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~HCC~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~HDSN~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~HHT~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~HL~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~HMY~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~HOLCO.AS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~HRT.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~HUN~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~HWKN~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~HYMC~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~HZM.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~IAG~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ICL~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~IFF.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~IFF~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~IFP.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~III.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~IKNX~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~IMCD.AS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~IMG.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~INA.LS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~INV.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~IOSP~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~IPHS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~IPI~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ITH.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ITP~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~IVN.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~JAG.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~JCQ.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~JCTCF~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~JHX~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~K.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~KALU~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~KER.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~KGC~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~KLDX~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~KL~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~KMG~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~KOP~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~KOR.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~KRA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~KRN.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~KRO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~KS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~KWR~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~LAC.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~LAC~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~LAM.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~LGO.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~LHN.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~LIF.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~LIN~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~LN.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~LOMA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~LOOP~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~LTHM~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~LUC.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~LUG.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~LUN.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~LXU~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~LYB~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MAG.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MAG~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MAW.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MAX.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MBII~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MDI.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MDU~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ME.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MEOH~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MERC~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~METC~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~METEX.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MKD~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MLBAT.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MLDYN.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MLM~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MLOLM.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MLPFX.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MLZAM.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MMX~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MND.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MON~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MOS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MOZ.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MPVDF~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MSV.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MT.AS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MTA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MTL~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MTRN~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MTX~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MT~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MUX.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MUX~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~MX.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NAK~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NB.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NCF.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NCU.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NDM.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NEM~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NEU~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NEXA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NG.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NGD.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NGD~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NGVT~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NG~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NK.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NML.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NPK.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NP~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NTIC~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NTR.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NTR~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NUE~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NVG.LS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~NYR.BR~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~OCI.AS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~OCIP~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~ODC~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Basic Materials\\year\\Balance Sheet\\year~OEC~balance_sheet.csv',
# ...
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~ARCO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~ARD~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~ARKR~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~ARMK~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~ASNA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~ASP.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~ATI.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~ATR~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~ATV~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~ATZ.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~AUGR.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~AVHI~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~AXL~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~AYRO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~AZO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BABA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BAIN.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BALTA.BR~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BBBY~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BBED.AS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BBQ~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BBRG~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BBW~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BBX~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BBY~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BCI.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BC~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BDL~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BELI.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BEL~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BEN.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BERY~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BFAM~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BFIT.AS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BGFV~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BGI~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BH-A~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BH~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BID~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BJRI~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BKE~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BKNG~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BKS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BLBD~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BLL~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BLMN~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BLNK~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BMS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BNED~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BOJA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BOOT~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BOY.TO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BSET~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BTN~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BUI.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BUR.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BURG~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BURL~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BWA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BXG~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BYD~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BZH~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~BZUN~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CAAS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CAFO.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CAKE~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CALI~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CAL~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CARS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CATG.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CATO~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CBD~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CBK~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CBRL~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CBS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CCK~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CCL~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CCS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CCZ~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CDA.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CDI.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CDTI~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CETV~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CHDN~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CHH~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CHSR.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CHS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CHUY~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CHWY~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CLAR~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CLUB~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CMG~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CNNE~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CNTY~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CNV.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~COLM~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CONN~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CPHC~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CPRI~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CPS~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CRI.PA~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CRI~balance_sheet.csv',
#  '../Charts_TenDollarData/financial_statements/data/Historical Financial Statements\\Consumer Cyclical\\year\\Balance Sheet\\year~CRMT~balance_sheet.csv',
#  ...]

# %%
sectors_list = []
symbols_list = []
columns_list = []
all_bs_file_names = [os.path.basename(x) for x in all_bs_abs_path]
all_bs_symbols = [os.path.basename(x).split("~")[1] for x in all_bs_abs_path]
for n,x in enumerate(all_cf_abs_path):
    x = x.replace("\\","/")
    sector = x.split("/")[5]
    sectors_list.append(sector)
    symbol = x.split("~")[1]
    symbols_list.append(symbol)
    df=pd.read_csv(x)
    columns = list(df)
    columns_list.append(columns)
    print(n, sector, symbol)
# Out:
# 0 Basic Materials AAU
# 1 Basic Materials AA
# 2 Basic Materials ABX.TO
# 3 Basic Materials ACET
# 4 Basic Materials ACH
# 5 Basic Materials ADN.TO
# 6 Basic Materials AEM.TO
# 7 Basic Materials AEM
# 8 Basic Materials AGI.TO
# 9 Basic Materials AGI
# 10 Basic Materials AG
# 11 Basic Materials AHGP
# 12 Basic Materials AI.PA
# 13 Basic Materials AKE.PA
# 14 Basic Materials AKS
# 15 Basic Materials AKZA.AS
# 16 Basic Materials ALAMG.PA
# 17 Basic Materials ALBKK.PA
# 18 Basic Materials ALB
# 19 Basic Materials ALCOI.PA
# 20 Basic Materials ALCRB.PA
# 21 Basic Materials ALDUB.PA
# 22 Basic Materials ALEO2.PA
# 23 Basic Materials ALGLD.PA
# 24 Basic Materials ALHRG.PA
# 25 Basic Materials ALMOU.PA
# 26 Basic Materials ALO
# 27 Basic Materials ALS.TO
# 28 Basic Materials ALTR.LS
# 29 Basic Materials AMEBA.PA
# 30 Basic Materials AMG.AS
# 31 Basic Materials AMM.TO
# 32 Basic Materials AMRS
# 33 Basic Materials ANX.TO
# 34 Basic Materials APAM.AS
# 35 Basic Materials APA
# 36 Basic Materials APD
# 37 Basic Materials APY.TO
# 38 Basic Materials AQA.TO
# 39 Basic Materials AR.TO
# 40 Basic Materials ARG.TO
# 41 Basic Materials ASH
# 42 Basic Materials ASIX
# 43 Basic Materials ASM
# 44 Basic Materials ASR.TO
# 45 Basic Materials AUG.TO
# 46 Basic Materials AUG
# 47 Basic Materials AUMN
# 48 Basic Materials AUY
# 49 Basic Materials AU
# 50 Basic Materials AVD
# 51 Basic Materials AVL.TO
# 52 Basic Materials AVTR
# 53 Basic Materials AVTX.AS
# 54 Basic Materials AXS.AS
# 55 Basic Materials AXTA
# 56 Basic Materials AXU
# 57 Basic Materials AYM.TO
# 58 Basic Materials BAK
# 59 Basic Materials BBL
# 60 Basic Materials BCC
# 61 Basic Materials BCPC
# 62 Basic Materials BHP
# 63 Basic Materials BIOX
# 64 Basic Materials BKI.TO
# 65 Basic Materials BOS.TO
# 66 Basic Materials BSX.TO
# 67 Basic Materials BTG
# 68 Basic Materials BTO.TO
# 69 Basic Materials BVN
# 70 Basic Materials CADC
# 71 Basic Materials CAL.TO
# 72 Basic Materials CAS.TO
# 73 Basic Materials CBPX
# 74 Basic Materials CBT
# 75 Basic Materials CCF
# 76 Basic Materials CCM.TO
# 77 Basic Materials CC
# 78 Basic Materials CDE
# 79 Basic Materials CEE.TO
# 80 Basic Materials CENX
# 81 Basic Materials CE
# 82 Basic Materials CFF.TO
# 83 Basic Materials CFP.TO
# 84 Basic Materials CFX.TO
# 85 Basic Materials CF
# 86 Basic Materials CG.TO
# 87 Basic Materials CGA
# 88 Basic Materials CGG.TO
# 89 Basic Materials CHNR
# 90 Basic Materials CIA.TO
# 91 Basic Materials CINR
# 92 Basic Materials CLF
# 93 Basic Materials CLW
# 94 Basic Materials CMC
# 95 Basic Materials CMP
# 96 Basic Materials CMT
# 97 Basic Materials CNT.TO
# 98 Basic Materials COR.LS
# 99 Basic Materials CPAC
# 100 Basic Materials CRBN.AS
# 101 Basic Materials CRH
# 102 Basic Materials CS.TO
# 103 Basic Materials CSTE
# 104 Basic Materials CSTM
# 105 Basic Materials CTVA
# 106 Basic Materials CWX.TO
# 107 Basic Materials CX
# 108 Basic Materials DD
# 109 Basic Materials DNG.TO
# 110 Basic Materials DNT.TO
# 111 Basic Materials DOW
# 112 Basic Materials DPM.TO
# 113 Basic Materials DRD
# 114 Basic Materials DSM.AS
# 115 Basic Materials ECL
# 116 Basic Materials ECO.TO
# 117 Basic Materials EDR.TO
# 118 Basic Materials EDV.TO
# 119 Basic Materials EGO
# 120 Basic Materials ELD.TO
# 121 Basic Materials ELR.TO
# 122 Basic Materials EMN
# 123 Basic Materials EMX
# 124 Basic Materials ENGB.BR
# 125 Basic Materials EOX.TO
# 126 Basic Materials EQX
# 127 Basic Materials ER.TO
# 128 Basic Materials ERA.PA
# 129 Basic Materials ERD.TO
# 130 Basic Materials ESI
# 131 Basic Materials ESM.TO
# 132 Basic Materials ETG.TO
# 133 Basic Materials EUR.PA
# 134 Basic Materials EVA
# 135 Basic Materials EXAC.PA
# 136 Basic Materials EXK
# 137 Basic Materials EXN.TO
# 138 Basic Materials EXPL.PA
# 139 Basic Materials EXP
# 140 Basic Materials FAR.TO
# 141 Basic Materials FCX
# 142 Basic Materials FELP
# 143 Basic Materials FF
# 144 Basic Materials FM.TO
# 145 Basic Materials FMC
# 146 Basic Materials FNV.TO
# 147 Basic Materials FNV
# 148 Basic Materials FOE
# 149 Basic Materials FR.TO
# 150 Basic Materials FRD
# 151 Basic Materials FSI
# 152 Basic Materials FSM
# 153 Basic Materials FSY.TO
# 154 Basic Materials FT.TO
# 155 Basic Materials FUL
# 156 Basic Materials FVI.TO
# 157 Basic Materials FVL.TO
# 158 Basic Materials GAU
# 159 Basic Materials GCM.TO
# 160 Basic Materials GCP
# 161 Basic Materials GDL.TO
# 162 Basic Materials GEO.TO
# 163 Basic Materials GEVO
# 164 Basic Materials GFI
# 165 Basic Materials GGA.TO
# 166 Basic Materials GGB
# 167 Basic Materials GGD.TO
# 168 Basic Materials GLT
# 169 Basic Materials GMO.TO
# 170 Basic Materials GMO
# 171 Basic Materials GMX.TO
# 172 Basic Materials GOLD
# 173 Basic Materials GORO
# 174 Basic Materials GPL
# 175 Basic Materials GPR.TO
# 176 Basic Materials GPRE
# 177 Basic Materials GRA
# 178 Basic Materials GRVO.PA
# 179 Basic Materials GSC.TO
# 180 Basic Materials GSM
# 181 Basic Materials GSS
# 182 Basic Materials GSV
# 183 Basic Materials GURE
# 184 Basic Materials GUY.TO
# 185 Basic Materials HBM.TO
# 186 Basic Materials HBM
# 187 Basic Materials HCC
# 188 Basic Materials HDSN
# 189 Basic Materials HHT
# 190 Basic Materials HL
# 191 Basic Materials HMY
# 192 Basic Materials HOLCO.AS
# 193 Basic Materials HRT.TO
# 194 Basic Materials HUN
# 195 Basic Materials HWKN
# 196 Basic Materials HYMC
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-ff460adbf4d7> in <module>
#      10     symbol = x.split("~")[1]
#      11     symbols_list.append(symbol)
# ---> 12     df=pd.read_csv(x)
#      13     columns = list(df)
#      14     columns_list.append(columns)
#
# ~\quantconnect\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# ~\quantconnect\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# ~\quantconnect\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# ~\quantconnect\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# ~\quantconnect\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# KeyboardInterrupt:

# %%
# for balance sheets, 1 set of columns. perfect
# for income statements, 1 set of columns. perfect
# for cash flow statements, 1 set of columns. perfect

set_columns_list = set((tuple(row) for row in columns_list))
len(list(set_columns_list)) #1
# len(list(set((str(row) for row in columns_list))))
# Out:
# 0

# %%
# bs_list = pd.DataFrame({
# is_list = pd.DataFrame({
cf_list = pd.DataFrame({
    'sectors_list': sectors_list,
    'symbols_list': symbols_list
})

# %%
bs_list.to_csv("../reference_data/balance_sheets_list.csv")
cf_list.to_csv("../reference_data/cash_flows_list.csv")
is_list.to_csv("../reference_data/income_statements_list.csv")

# %%
len(list(set((str(row) for row in columns_list))))
# Out:
# 1
